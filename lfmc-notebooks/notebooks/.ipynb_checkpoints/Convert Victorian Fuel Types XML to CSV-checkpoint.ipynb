# %%
import xml.etree.ElementTree as ET
import csv

tree = ET.parse("/media/arawlins/Backups/DataSources/geoserver_data/FuelModels/Fuel_All_States/VIC/FuelTypes_2tha.xml")
root = tree.getroot()

# open a file for writing

_data = open('/tmp/fuel_types_LUT.csv', 'w')

# create the csv writer object

csvwriter = csv.writer(_data)
_head = []

count = 0
for member in root.findall('Fuel_Type'):
    fuel_type = []
    
    if count == 0:
        Id = member.find('Id').tag
        _head.append(Id)

        Type_Name = member.find('Type_Name').tag
        _head.append(Type_Name)

        Description = member.find('Description').tag
        _head.append(Description)

        Surface_r = member.find('Surface_r').tag
        _head.append(Surface_r)

        Surface_k = member.find('Surface_k').tag
        _head.append(Surface_k)

        Surface_c = member.find('Surface_c').tag
        _head.append(Surface_c)

        Elevated_r = member.find('Elevated_r').tag
        _head.append(Elevated_r)

        Elevated_k = member.find('Elevated_k').tag
        _head.append(Elevated_k)

        Elevated_c = member.find('Elevated_c').tag
        _head.append(Elevated_c)

        Bark_r = member.find('Bark_r').tag
        _head.append(Bark_r)

        Bark_k = member.find('Bark_k').tag
        _head.append(Bark_k)

        Bark_c = member.find('Bark_c').tag
        _head.append(Bark_c)

        Wind_Reduction_Factor = member.find('Wind_Reduction_Factor').tag
        _head.append(Wind_Reduction_Factor)

        csvwriter.writerow(_head)
        count = count + 1

    Id = member.find('Id').text
    fuel_type.append(Id)

    Type_Name = member.find('Type_Name').text
    fuel_type.append(Type_Name)

    Description = member.find('Description').text
    fuel_type.append(Description)

    Surface_r = member.find('Surface_r').text
    fuel_type.append(Surface_r)

    Surface_k = member.find('Surface_k').text
    fuel_type.append(Surface_k)

    Surface_c = member.find('Surface_c').text
    fuel_type.append(Surface_c)

    Elevated_r = member.find('Elevated_r').text
    fuel_type.append(Elevated_r)

    Elevated_k = member.find('Elevated_k').text
    fuel_type.append(Elevated_k)

    Elevated_c = member.find('Elevated_c').text
    fuel_type.append(Elevated_c)

    Bark_r = member.find('Bark_r').text
    fuel_type.append(Bark_r)

    Bark_k = member.find('Bark_k').text
    fuel_type.append(Bark_k)

    Bark_c = member.find('Bark_c').text
    fuel_type.append(Bark_c)

    Wind_Reduction_Factor = member.find('Wind_Reduction_Factor').text
    fuel_type.append(Wind_Reduction_Factor)

    csvwriter.writerow(fuel_type)
_data.close()

# %%
import pandas as pd

ds = pd.read_csv('/tmp/fuel_types_LUT.csv')
ds
# Out:
#     Id                               Type_Name  \
# 0    0              Water, sand, no vegetation
# 1    1                         Moist Shrubland
# 2    2                          Moist Woodland
# 3    3                    Low flammable Shrubs
# 4    4             Moist Sedgeland / Grassland
# 5    5                          Woodland Heath
# 6    6                       Forest with shrub
# 7    7                        Forest herb-rich
# 8    8             Dry Open Forest shrub/herbs
# 9    9                Woodland Grass/Herb-rich
# 10  10                        Sparse shrubland
# 11  11            Wet Forest shrub & wiregrass
# 12  12                      Damp Forest  shrub
# 13  13                   Riparian Forest shrub
# 14  14                      Riparian shrubland
# 15  15                              Rainforest
# 16  16               High Elevation Grassland
# 17  17          High Elevation Shrubland/Heath
# 18  18           High Elevation Woodland shrub
# 19  19           High Elevation Woodland grass
# 20  20        Temperate Grassland / Sedgeland
# 21  21        Broombush / Shrubland / Tea-tree
# 22  22                Woodland bracken/shrubby
# 23  23                               Wet Heath
# 24  24                               Dry Heath
# 25  25                      Mallee shrub/heath
# 26  26                         Mallee spinifex
# 27  27                         Mallee chenopod
# 28  28                Woodland Callitris/Belah
# 29  29             Ephemeral grass/sedge/herbs
# 30  30                  Moorland / Fjaeldmarks
# 31  31                    Dry Closed Shrubland
# 32  32  Wet Forest with rainforest understorey
# 33  33                            Swamp Forest
# 34  34                            Wet herbland
# 35  35                               Wet Scrub
# 36  36                         Alpine Herbland
# 37  37                            Wet Herbland
# 38  38               Mangroves / Aquatic Herbs
# 39  39                      Savanna grasslands
# 40  40           Semi-mesic Sclerophyll forest
# 41  41                Gum Woodland heath/shrub
# 42  42                            Mallee grass
# 43  43                Gum Woodland grass/herbs
# 44  44                       Hummock grassland
# 45  45                       Dry Forest shrubs
# 46  97                      Orchard / Vineyard
# 47  98                     Softwood Plantation
# 48  99                     Hardwood Plantation
# 49  46                         Eaten Out Grass
# 50  47                             Residential
#
#                                           Description  Surface_r  Surface_k  \
# 0                                         fuel absent       0.00       0.00
# 1                      dense shrubland, salt affected       1.50       0.25
# 2   low trees, shrubby, sedgy understorey, bark ha...       2.00       0.20
# 3   low flammability except after exceptional rain...       1.00       0.20
# 4   dense sward, potentially high dead component, ...       3.80       0.70
# 5               flammable shrubs and high bark hazard       2.50       0.15
# 6   potentially high bark hazard, shrubs moderate ...       3.00       0.15
# 7   potentially high bark hazard, little elevated ...       2.50       0.25
# 8   dry forest with open understorey (northern jar...       1.50       0.40
# 9          surface fuels dominated by grass and herbs       1.70       0.25
# 10  sparse shrubby vegetation with discontinuous s...       1.50       0.25
# 11  high biomass forest, but with little dead susp...       3.70       0.31
# 12  dense understorey and potentially high bark ha...       3.30       0.67
# 13  dense vegetation but with a small proportion o...       3.00       0.20
# 14         dense vegetation with little dead material       1.80       0.20
# 15  dense vegetation with little dead material, ep...       1.80       0.20
# 16  dense sward of tussock grasses or herbs, high ...       2.30       0.67
# 17  dense cover of shrubs with surface fuel largel...       1.60       0.10
# 18               wooded area with shrubby understorey       2.00       0.20
# 19         wooded area with continuous grass tussocks       3.00       0.25
# 20  grasses and sedges widespread, but varying in ...       0.76       0.61
# 21  dense shrubland, but with relatively low level...       1.50       0.25
# 22  wooded area with varying understorey, but not ...       3.00       0.25
# 23  dense heath possibly with dense sedgy undergrowth       2.00       0.57
# 24  dense heath with significant amounts of dead m...       1.20       0.60
# 25  continuous shrub layer but amount of dead mate...       1.50       0.25
# 26  discontinuous fuels, very flammable under wind...       3.00       0.10
# 27  low flammability except after exceptional rain...       1.50       0.30
# 28  low flammability except after exceptional rain...       1.50       0.35
# 29  dense grass and sedges with potentially high l...       2.50       0.25
# 30                    low flammability cushion plants       0.70       0.15
# 31  tea-tree or paperbark thickets, little underst...       1.80       0.20
# 32      wet sclerophyll forest with mesic understorey       2.50       0.40
# 33     dense Melaleuca forest with little understorey       1.00       0.25
# 34                      freshwater herbs on mud flats       1.00       0.60
# 35  flammable shrubland with high level of dead el...       1.50       0.35
# 36             dense, upright, low flammability herbs       1.50       0.20
# 37  low herbs in seasonally inundated lakebeds or ...       1.00       0.70
# 38  trees, shrubs and herbs in permanent water, un...       0.00       0.00
# 39         tall flammable grasses in an open woodland       2.50       0.60
# 40  forest with semi-mesic shurbs and flammable gr...       3.50       0.60
# 41  gum woodland with moderate bark hazard, heath/...       2.50       0.40
# 42  mallee woodland with predominantly grass under...       2.80       0.40
# 43  gum woodland with moderate bark hazard, herbac...       2.50       0.60
# 44     hummock grassland, discontinuous surface fuels       3.70       0.15
# 45  dry forest with continuous understorey, (south...       3.20       0.15
# 46                                orchard or vineyard       1.00       0.80
# 47         dense canopy with continuous surface fuels       3.30       0.60
# 48       uniform canopy with continuous surface fuels       3.00       0.60
# 49                                                NaN       0.63       1.00
# 50                                                NaN       0.02       1.00
#
#     Surface_c  Elevated_r  Elevated_k  Elevated_c  Bark_r  Bark_k  Bark_c  \
# 0        0.06         0.0        0.00         0.0    0.00    0.00    0.00
# 1        0.50         2.5        0.20         1.5    2.78    0.19    0.83
# 2        2.00         2.5        0.15         1.5    2.00    0.25    2.00
# 3        0.20         0.0        0.00         0.0    0.00    0.00    0.00
# 4        0.00         0.0        0.00         0.0    0.00    0.00    0.00
# 5        1.00         3.5        0.08         1.0    3.00    0.10    1.00
# 6        1.50         2.8        0.25         1.2    2.10    0.25    2.00
# 7        1.20         1.5        0.20         1.5    2.10    0.25    2.00
# 8        1.20         2.0        0.35         1.0    0.80    0.35    2.20
# 9        0.70         1.5        0.20         1.0    2.50    0.20    0.70
# 10       0.50         1.5        0.20         0.5    0.00    0.00    0.00
# 11       1.30         4.0        0.30         1.0    2.50    0.20    2.50
# 12       1.50         3.5        0.25         1.2    3.50    0.25    1.50
# 13       1.00         2.7        0.15         1.0    2.20    0.12    2.00
# 14       1.00         2.7        0.25         1.0    0.00    0.00    0.00
# 15       1.00         1.0        0.35         1.0    1.00    0.25    1.00
# 16       0.40         0.0        0.00         0.0    0.00    0.00    0.00
# 17       0.60         2.5        0.25         1.5    0.00    0.00    0.00
# 18       1.00         2.5        0.15         1.0    2.00    0.25    1.00
# 19       1.00         1.0        0.35         1.0    1.00    0.25    1.00
# 20       0.08         0.0        0.00         0.0    0.00    0.00    0.00
# 21       0.50         2.0        0.35         1.0    0.00    0.00    0.00
# 22       1.00         3.0        0.25         1.2    2.50    0.20    2.00
# 23       0.00         3.6        0.47         1.0    0.00    0.00    0.00
# 24       0.80         3.8        0.60         0.7    0.00    0.00    0.00
# 25       1.00         3.4        0.80         0.5    3.00    0.30    1.00
# 26       0.50         1.5        0.70         0.5    3.00    0.15    1.00
# 27       0.50         1.0        0.25         0.0    3.00    0.15    1.00
# 28       1.20         1.0        0.35         1.0    0.00    0.00    0.00
# 29       1.00         0.0        0.00         0.0    0.00    0.00    0.00
# 30       0.30         0.0        0.00         0.0    0.00    0.00    0.00
# 31       0.20         3.0        0.35         1.0    2.50    0.15    0.50
# 32       1.50         2.0        0.25         0.0    2.50    0.20    2.50
# 33       0.00         1.0        0.35         0.5    2.00    0.15    0.20
# 34       0.60         0.0        0.00         0.0    0.00    0.00    0.00
# 35       1.00         4.0        0.50         1.0    2.50    0.15    0.50
# 36       0.50         0.0        0.00         0.0    0.00    0.00    0.00
# 37       0.00         0.0        0.00         0.0    0.00    0.00    0.00
# 38       0.00         0.0        0.00         0.0    0.00    0.00    0.00
# 39       0.50         1.5        0.20         0.5    1.00    0.15    0.20
# 40       0.50         2.5        0.30         0.5    3.00    0.15    1.00
# 41       0.50         3.0        0.30         0.0    1.00    0.20    1.00
# 42       0.20         2.0        0.15         0.0    2.50    0.15    0.50
# 43       0.50         1.5        0.20         0.5    1.00    0.20    1.00
# 44       0.30         0.0        0.00         0.0    0.00    0.00    0.00
# 45       0.80         2.8        0.10         0.2    3.80    0.15    0.20
# 46       0.10         0.0        0.00         0.0    0.00    0.00    0.00
# 47       0.70         1.5        0.20         1.5    2.00    0.34    0.00
# 48       0.70         1.0        0.50         0.0    4.00    0.45    0.00
# 49       0.00         0.0        0.00         0.0    0.00    0.00    0.00
# 50       0.00         0.0        0.00         0.0    0.00    0.00    0.00
#
#     Wind_Reduction_Factor
# 0                     1.0
# 1                     2.0
# 2                     3.0
# 3                     1.2
# 4                     1.5
# 5                     2.5
# 6                     3.5
# 7                     3.0
# 8                     3.0
# 9                     2.5
# 10                    1.8
# 11                    4.5
# 12                    4.0
# 13                    5.0
# 14                    2.5
# 15                    5.0
# 16                    1.2
# 17                    1.5
# 18                    2.5
# 19                    2.5
# 20                    1.2
# 21                    2.0
# 22                    3.0
# 23                    2.0
# 24                    1.5
# 25                    1.5
# 26                    1.5
# 27                    2.0
# 28                    2.5
# 29                    1.2
# 30                    1.0
# 31                    4.0
# 32                    4.5
# 33                    4.0
# 34                    1.2
# 35                    1.5
# 36                    1.2
# 37                    1.2
# 38                    3.5
# 39                    2.0
# 40                    3.5
# 41                    2.5
# 42                    1.5
# 43                    2.5
# 44                    1.2
# 45                    3.5
# 46                    1.5
# 47                    4.5
# 48                    4.0
# 49                    1.0
# 50                    2.5

# %%
ds.to_csv('/media/arawlins/Backups/DataSources/geoserver_data/FuelModels/Fuel_All_States/VIC/fuel_types_lut.csv')
